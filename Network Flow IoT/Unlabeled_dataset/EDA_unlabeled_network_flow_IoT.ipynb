# %%
from google.colab import drive

drive.mount('/content/drive')
datasheet = '/content/drive/My Drive/Datasheet/DDoS/unlabeled_dataset.csv'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv(datasheet)

# %%
df.describe()
# Out:
#          Unnamed: 0            dt     switch      pktcount     bytecount  \
# count  5.051899e+06  5.051899e+06  5051899.0  5.051899e+06  5.051899e+06
# mean   2.525949e+06  4.305357e-02        0.0  2.108956e+05  2.507370e+08
# std    1.458358e+06  3.074109e-01        0.0  1.261431e+05  1.440351e+08
# min    0.000000e+00 -5.900000e-05        0.0  1.000000e+00  6.800000e+01
# 25%    1.262974e+06  1.200000e-05        0.0  1.018675e+05  1.260193e+08
# 50%    2.525949e+06  4.500000e-05        0.0  2.087170e+05  2.529195e+08
# 75%    3.788924e+06  4.790000e-04        0.0  3.149300e+05  3.779684e+08
# max    5.051898e+06  4.059949e+01        0.0  5.383070e+05  4.948971e+08
#
#                 dur   dur_nsec       tot_dur         flows     packetins  ...  \
# count  5.051899e+06  5051899.0  5.051899e+06  5.051899e+06  5.051899e+06  ...
# mean   4.305357e-02        0.0  4.305357e-02  7.567258e+02  2.101388e+05  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5051899 entries, 0 to 5051898
# Data columns (total 24 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Unnamed: 0   int64
#  1   dt           float64
#  2   switch       int64
#  3   src          object
#  4   dst          object
#  5   pktcount     int64
#  6   bytecount    int64
#  7   dur          float64
#  8   dur_nsec     int64
#  9   tot_dur      float64
#  10  flows        int64
#  11  packetins    int64
#  12  pktperflow   float64
#  13  byteperflow  float64
#  14  pktrate      float64
#  15  Pairflow     int64
#  16  Protocol     object
#  17  port_no      int64
#  18  tx_bytes     int64
#  19  rx_bytes     int64
#  20  tx_kbps      float64
#  21  rx_kbps      float64
#  22  tot_kbps     float64
#  23  label        float64
# dtypes: float64(10), int64(11), object(3)
# memory usage: 925.0+ MB

# %%
df.head(5)
# Out:
#    Unnamed: 0        dt  switch             src          dst  pktcount  \
# 0           0  0.107169       0   160.202.128.1   10.10.11.7    367006
# 1           1  0.000043       0  107.151.203.70  10.10.1.198    390913
# 2           2  0.000029       0  107.151.203.70  10.10.1.198    350145
# 3           3  0.000000       0  107.151.203.70  10.10.1.198    460043
# 4           4  0.221046       0  107.151.203.70  10.10.1.198    430840
#
#    bytecount       dur  dur_nsec   tot_dur  ...   pktrate  Pairflow  Protocol  \
# 0  474225253  0.107169         0  0.107169  ...  0.000216      3714      ICMP
# 1  445265315  0.000043         0  0.000043  ...  0.000232      1892      ICMP
# 2  435310143  0.000029         0  0.000029  ...  0.000208       864      ICMP
# 3  461667843  0.000000         0  0.000000  ...  0.000273      3720      ICMP
# 4  454911261  0.221046         0  0.221046  ...  0.000255      2888      ICMP
#
# ...

# %%
df.tail(5)
# Out:
#          Unnamed: 0        dt  switch          src          dst  pktcount  \
# 5051894     5051894  0.000163       0  10.10.1.123  10.10.1.127    322468
# 5051895     5051895  0.287269       0  10.10.1.123  10.10.1.127    432630
# 5051896     5051896  0.750035       0  10.10.1.123  10.10.1.127    395288
# 5051897     5051897  0.000195       0  10.10.1.123  10.10.1.127    254856
# 5051898     5051898  0.750161       0  10.10.1.123  10.10.1.127    366190
#
#          bytecount       dur  dur_nsec   tot_dur  ...   pktrate  Pairflow  \
# 5051894  396538506  0.000163         0  0.000163  ...  0.000191       555
# 5051895  465802005  0.287269         0  0.287269  ...  0.000256      4721
# 5051896  440596123  0.750035         0  0.750035  ...  0.000234      5538
# 5051897  269499077  0.000195         0  0.000195  ...  0.000151      4286
# 5051898  451318386  0.750161         0  0.750161  ...  0.000217       900
#
#          Protocol  port_no  tx_bytes   rx_bytes tx_kbps       rx_kbps  \
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.head(5)
# Out:
#          dt  switch             src          dst  pktcount  bytecount  \
# 0  0.107169       0   160.202.128.1   10.10.11.7    367006  474225253
# 1  0.000043       0  107.151.203.70  10.10.1.198    390913  445265315
# 2  0.000029       0  107.151.203.70  10.10.1.198    350145  435310143
# 3  0.000000       0  107.151.203.70  10.10.1.198    460043  461667843
# 4  0.221046       0  107.151.203.70  10.10.1.198    430840  454911261
#
#         dur  dur_nsec   tot_dur  flows  ...   pktrate  Pairflow  Protocol  \
# 0  0.107169         0  0.107169   3753  ...  0.000216      3714      ICMP
# 1  0.000043         0  0.000043   1978  ...  0.000232      1892      ICMP
# 2  0.000029         0  0.000029    929  ...  0.000208       864      ICMP
# 3  0.000000         0  0.000000   3830  ...  0.000273      3720      ICMP
# 4  0.221046         0  0.221046   2980  ...  0.000255      2888      ICMP
#
#    port_no  tx_bytes   rx_bytes  tx_kbps       rx_kbps      tot_kbps  label
# ...

# %%
df.describe()
# Out:
#                  dt     switch      pktcount     bytecount           dur  \
# count  5.051899e+06  5051899.0  5.051899e+06  5.051899e+06  5.051899e+06
# mean   4.305357e-02        0.0  2.108956e+05  2.507370e+08  4.305357e-02
# std    3.074109e-01        0.0  1.261431e+05  1.440351e+08  3.074109e-01
# min   -5.900000e-05        0.0  1.000000e+00  6.800000e+01 -5.900000e-05
# 25%    1.200000e-05        0.0  1.018675e+05  1.260193e+08  1.200000e-05
# 50%    4.500000e-05        0.0  2.087170e+05  2.529195e+08  4.500000e-05
# 75%    4.790000e-04        0.0  3.149300e+05  3.779684e+08  4.790000e-04
# max    4.059949e+01        0.0  5.383070e+05  4.948971e+08  4.059949e+01
#
#         dur_nsec       tot_dur         flows     packetins    pktperflow  \
# count  5051899.0  5.051899e+06  5.051899e+06  5.051899e+06  5.051899e+06
# mean         0.0  4.305357e-02  7.567258e+02  2.101388e+05  3.655555e+03
# std          0.0  3.074109e-01  1.926003e+03  1.251987e+05  3.360927e+03
# ...

# %%
df.shape
# Out:
# (5051899, 23)

# %%
df['label'].nunique()
# Out:
# 0

# %%
df['tx_bytes'].nunique()
# Out:
# 1

# %%
df['dur_nsec'].nunique()
# Out:
# 1

# %%
df['dt'].unique()
# Out:
# array([1.07169e-01, 4.30000e-05, 2.90000e-05, ..., 7.49628e-01,
#        2.73871e-01, 1.72758e-01])

# %%
df['src'].nunique()
# Out:
# 2424

# %%
df['src'].unique()
# Out:
# array(['160.202.128.1', '107.151.203.70', '127.0.0.1', ...,
#        '91.189.91.157', '185.125.190.56', '91.189.94.4'], dtype=object)

# %%
print(df.isnull().sum())
# Out:
# dt                   0
# switch               0
# src                  0
# dst                  0
# pktcount             0
# bytecount            0
# dur                  0
# dur_nsec             0
# tot_dur              0
# flows                0
# packetins            0
# pktperflow           0
# byteperflow          0
# pktrate              0
# Pairflow             0
# Protocol             0
# port_no              0
# tx_bytes             0
# rx_bytes             0
# tx_kbps              0
# rx_kbps              0
# tot_kbps             0
# label          5051899
# dtype: int64

# %%
df['dur'].nunique()
# Out:
# 258723

# %%
df['dur'].unique()
# Out:
# array([1.07169e-01, 4.30000e-05, 2.90000e-05, ..., 7.49628e-01,
#        2.73871e-01, 1.72758e-01])

# %%
# Nilai minimum kolom dt

df[df['dt']< -0]
# Out:
#                dt  switch             src            dst  pktcount  bytecount  \
# 36186   -0.000009       0     10.10.1.198  77.247.108.45    379420  438313458
# 59472   -0.000001       0  172.217.194.95     10.10.11.7    199840  253269581
# 60666   -0.000026       0   74.125.130.95    10.10.1.198    286483  352411601
# 61936   -0.000001       0  142.251.175.95     10.10.11.7     59201   98464218
# 101010  -0.000001       0   74.125.130.95    10.10.1.198    307901  379606386
# ...           ...     ...             ...            ...       ...        ...
# 5032815 -0.000001       0       127.0.0.1     127.0.0.53    327649  459985347
# 5041249 -0.000007       0      127.0.0.53      127.0.0.1    327236  341202527
# 5045144 -0.000002       0      127.0.0.53      127.0.0.1    188258  227675695
# 5048267 -0.000001       0       127.0.0.1     127.0.0.53    327649  459985347
# 5051173 -0.000009       0      127.0.0.53      127.0.0.1    347905  411110723
#
# ...

# %%
# Nilai minimum dur

df[df['dur']< 0]
# Out:
#                dt  switch             src            dst  pktcount  bytecount  \
# 36186   -0.000009       0     10.10.1.198  77.247.108.45    379420  438313458
# 59472   -0.000001       0  172.217.194.95     10.10.11.7    199840  253269581
# 60666   -0.000026       0   74.125.130.95    10.10.1.198    286483  352411601
# 61936   -0.000001       0  142.251.175.95     10.10.11.7     59201   98464218
# 101010  -0.000001       0   74.125.130.95    10.10.1.198    307901  379606386
# ...           ...     ...             ...            ...       ...        ...
# 5032815 -0.000001       0       127.0.0.1     127.0.0.53    327649  459985347
# 5041249 -0.000007       0      127.0.0.53      127.0.0.1    327236  341202527
# 5045144 -0.000002       0      127.0.0.53      127.0.0.1    188258  227675695
# 5048267 -0.000001       0       127.0.0.1     127.0.0.53    327649  459985347
# 5051173 -0.000009       0      127.0.0.53      127.0.0.1    347905  411110723
#
# ...

# %%
# Nilai minimum tot_dur
df[df['tot_dur']< 0]
# Out:
#                dt  switch             src            dst  pktcount  bytecount  \
# 36186   -0.000009       0     10.10.1.198  77.247.108.45    379420  438313458
# 59472   -0.000001       0  172.217.194.95     10.10.11.7    199840  253269581
# 60666   -0.000026       0   74.125.130.95    10.10.1.198    286483  352411601
# 61936   -0.000001       0  142.251.175.95     10.10.11.7     59201   98464218
# 101010  -0.000001       0   74.125.130.95    10.10.1.198    307901  379606386
# ...           ...     ...             ...            ...       ...        ...
# 5032815 -0.000001       0       127.0.0.1     127.0.0.53    327649  459985347
# 5041249 -0.000007       0      127.0.0.53      127.0.0.1    327236  341202527
# 5045144 -0.000002       0      127.0.0.53      127.0.0.1    188258  227675695
# 5048267 -0.000001       0       127.0.0.1     127.0.0.53    327649  459985347
# 5051173 -0.000009       0      127.0.0.53      127.0.0.1    347905  411110723
#
# ...

# %%
df['port_no'].nunique()
# Out:
# 26131

# %%
df['Protocol'].nunique()
# Out:
# 3

# %%
df['Protocol'].value_counts()
# Out:
# Protocol
# TCP     5000000
# ICMP      32763
# UDP       19136
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['Protocol'].value_counts(ascending=True).plot.bar(
    color = ['purple','green']
)
plt.title('Frekuensi Jumlah Protokol')
plt.xlabel('Protocol')
plt.ylabel('Frekuensi')
plt.xticks(rotation=0)
plt.show()
