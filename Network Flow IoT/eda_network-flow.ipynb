# %%
import pandas as pd

# Tampilkan semua kolom
pd.set_option('display.max_columns', None)
path = "D:/Politeknik Negeri Ujung Pandang/D4 Teknik Komputer dan Jaringan/Skripsi/CyberSecurity&DataScientiest/Datasheet/Mendeley Data DDoS/DH_label_only.csv"
df = pd.read_csv(path)

# %%
# Info DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104344 entries, 0 to 104343
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104344 non-null  float64
#  1   switch       104344 non-null  int64
#  2   src          104344 non-null  object
#  3   dst          104344 non-null  object
#  4   pktcount     104344 non-null  int64
#  5   bytecount    104344 non-null  int64
#  6   dur          104344 non-null  float64
#  7   dur_nsec     104344 non-null  int64
#  8   tot_dur      104344 non-null  float64
#  9   flows        104344 non-null  int64
#  10  packetins    104344 non-null  int64
#  11  pktperflow   104344 non-null  float64
#  12  byteperflow  104344 non-null  float64
#  13  pktrate      104344 non-null  float64
#  14  Pairflow     104344 non-null  int64
#  15  Protocol     104344 non-null  object
#  16  port_no      104344 non-null  int64
#  17  tx_bytes     104344 non-null  int64
# ...

# %%
# 5 Rows Data Pertama
df.head(5)
# Out:
#         dt  switch       src       dst  pktcount  bytecount    dur   dur_nsec  \
# 0  11425.0       1  10.0.0.1  10.0.0.8     45304   48294064  100.0  716000000
# 1  11605.0       1  10.0.0.1  10.0.0.8    126395  134737070  280.0  734000000
# 2  11425.0       1  10.0.0.2  10.0.0.8     90333   96294978  200.0  744000000
# 3  11425.0       1  10.0.0.2  10.0.0.8     90333   96294978  200.0  744000000
# 4  11425.0       1  10.0.0.2  10.0.0.8     90333   96294978  200.0  744000000
#
#         tot_dur  flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 0  1.010000e+11      3       1943     13535.0   14428310.0    451.0         0
# 1  2.810000e+11      2       1943     13531.0   14424046.0    451.0         0
# 2  2.010000e+11      3       1943     13534.0   14427244.0    451.0         0
# 3  2.010000e+11      3       1943     13534.0   14427244.0    451.0         0
# 4  2.010000e+11      3       1943     13534.0   14427244.0    451.0         0
#
# ...

# %%
# 5 Baris Data Terakhir
df.tail(5)
# Out:
#             dt  switch        src       dst  pktcount  bytecount   dur  \
# 104339  5262.0       3   10.0.0.5  10.0.0.7        79       7742  81.0
# 104340  5262.0       3   10.0.0.5  10.0.0.7        79       7742  81.0
# 104341  5262.0       3   10.0.0.5  10.0.0.7        79       7742  81.0
# 104342  5262.0       3  10.0.0.11  10.0.0.5        31       3038  31.0
# 104343  5262.0       3  10.0.0.11  10.0.0.5        31       3038  31.0
#
#          dur_nsec       tot_dur  flows  packetins  pktperflow  byteperflow  \
# 104339  842000000  8.184200e+10      5         10        29.0       2842.0
# 104340  842000000  8.184200e+10      5         10        29.0       2842.0
# 104341  842000000  8.184200e+10      5         10        29.0       2842.0
# 104342  805000000  3.180500e+10      5         10        30.0       2940.0
# 104343  805000000  3.180500e+10      5         10        30.0       2940.0
#
#         pktrate  Pairflow Protocol  port_no  tx_bytes  rx_bytes  tx_kbps  \
# ...

# %%
# Mengecek missing values
df.isnull().sum()
# Out:
# dt               0
# switch           0
# src              0
# dst              0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
# Ukuran dataframe (rows, colomns)
rows, columns = df.shape
print(f'Ukuran dari data frame ini terdiri dari {rows} baris dan {columns} kolom')
# Out:
# Ukuran dari data frame ini terdiri dari 103838 baris dan 23 kolom

# %%
# Total jumlah missing values
print('Total Jumlah missing values pada dataframe adalah:', df.isnull().sum().sum())
# Out:
# Total Jumlah missing values pada dataframe adalah: 1012

# %%
# Menghapus kolom missing values pada rx_kbps dan tot_kbps
df.dropna(subset=['tot_kbps','rx_kbps'], inplace=True)
print('Missing values setelah di drop menjadi:', df.isnull().sum().sum())
# Out:
# Missing values setelah di drop menjadi: 0

# %%
# Ringkasan Statistik DataFrame
df.describe()
# Out:
#                   dt         switch       pktcount     bytecount  \
# count  103838.000000  103838.000000  103838.000000  1.038380e+05
# mean    17999.576831       4.214507   52782.211175  3.801765e+07
# std     11962.219858       1.956326   52061.402494  4.874554e+07
# min      2488.000000       1.000000       0.000000  0.000000e+00
# 25%      7128.000000       3.000000     801.000000  7.930650e+04
# 50%     11965.000000       4.000000   42557.000000  6.409692e+06
# 75%     29982.000000       5.000000   94683.000000  7.597222e+07
# max     42935.000000      10.000000  260006.000000  1.471280e+08
#
#                  dur      dur_nsec       tot_dur          flows  \
# count  103838.000000  1.038380e+05  1.038380e+05  103838.000000
# mean      322.128922  4.613701e+08  3.225179e+11       5.666346
# std       283.926071  2.771012e+08  2.838104e+11       2.951026
# min         0.000000  0.000000e+00  0.000000e+00       2.000000
# ...

# %%
# Nilai minimum pktrate
df[df['pktrate']== -4365.000000]
# Out:
#             dt  switch       src       dst  pktcount  bytecount  dur  \
# 82379  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82380  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82381  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82382  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82383  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
#
#         dur_nsec       tot_dur  flows  packetins  pktperflow  byteperflow  \
# 82379  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82380  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82381  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82382  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82383  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
#
#        pktrate  Pairflow Protocol  port_no   tx_bytes   rx_bytes  tx_kbps  \
# ...

# %%
# Nilai minimum pktperflow
df[df['pktperflow']== -130933.000000]
# Out:
#             dt  switch       src       dst  pktcount  bytecount  dur  \
# 82379  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82380  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82381  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82382  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
# 82383  15666.0       5  10.0.0.2  10.0.0.8      2536     136944  7.0
#
#         dur_nsec       tot_dur  flows  packetins  pktperflow  byteperflow  \
# 82379  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82380  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82381  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82382  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
# 82383  609000000  7.609000e+09      5      13797   -130933.0 -146442594.0
#
#        pktrate  Pairflow Protocol  port_no   tx_bytes   rx_bytes  tx_kbps  \
# ...

# %%
# Nilai minimumn byteperflow
df[df['byteperflow'] < 0]
# Out:
#             dt  switch       src       dst  pktcount  bytecount   dur  \
# 20463   2740.0       1  10.0.0.2  10.0.0.3      2671    2847286   5.0
# 20465   2740.0       1  10.0.0.2  10.0.0.3      2671    2847286   5.0
# 20470   2740.0       1  10.0.0.1  10.0.0.3      2670    2846220   5.0
# 20472   2740.0       1  10.0.0.1  10.0.0.3      2670    2846220   5.0
# 20489   2740.0       1  10.0.0.2  10.0.0.3      2671    2847286   5.0
# ...        ...     ...       ...       ...       ...        ...   ...
# 82399  15695.0       2  10.0.0.2  10.0.0.8      8746     472284  28.0
# 82400  15695.0       2  10.0.0.2  10.0.0.8      8746     472284  28.0
# 82404  15695.0       1  10.0.0.2  10.0.0.8      6171     333234  21.0
# 82405  15695.0       1  10.0.0.2  10.0.0.8      6171     333234  21.0
# 82406  15695.0       1  10.0.0.2  10.0.0.8      6171     333234  21.0
#
#         dur_nsec       tot_dur  flows  packetins  pktperflow  byteperflow  \
# ...

# %%
df['src'].nunique()
# Out:
# 19

# %%
df['src'].unique()
# Out:
# array(['10.0.0.1', '10.0.0.2', '10.0.0.4', '10.0.0.10', '10.0.0.3',
#        '10.0.0.5', '10.0.0.13', '10.0.0.6', '10.0.0.20', '10.0.0.11',
#        '10.0.0.12', '10.0.0.18', '10.0.0.8', '10.0.0.7', '10.0.0.9',
#        '10.0.0.14', '10.0.0.15', '10.0.0.16', '10.0.0.17'], dtype=object)

# %%
df['src'].value_counts()
# Out:
# src
# 10.0.0.3     11395
# 10.0.0.7     10291
# 10.0.0.10     9593
# 10.0.0.1      8627
# 10.0.0.12     8081
# 10.0.0.2      8010
# 10.0.0.5      7291
# 10.0.0.9      7165
# 10.0.0.11     6382
# 10.0.0.4      5973
# 10.0.0.8      5210
# 10.0.0.6      2740
# 10.0.0.18     2590
# 10.0.0.13     2484
# 10.0.0.14     2265
# 10.0.0.15     1858
# 10.0.0.16     1789
# 10.0.0.20     1114
# 10.0.0.17      980
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['src'].value_counts(ascending=True).plot.barh(
    color=['lightgreen', 'purple']
)
plt.title('Frekuensi src request')
plt.xlabel('Frekuensi muncul')
plt.ylabel('IP Address Sender')
plt.show()

# %%
attack_src = df[df['label']==1]['src'].value_counts()

plt.figure(figsize=(14,8), dpi=100)
attack_src.plot(kind='barh', color='blue')

# Tambah label angka di samping bar
for idx, val in enumerate(attack_src.values):
    plt.text(val, idx, str(val), color='red', va='center', fontsize=10)

plt.xlabel('Number of Requests')
plt.ylabel('IP Address of Sender')
plt.title('Number of Attack Requests per Source IP')
plt.subplots_adjust(left=0.3)  # kasih ruang label IP
plt.show()

# %%
attack_src = df[df['label']==0]['src'].value_counts()

plt.figure(figsize=(14,8), dpi=100)
attack_src.plot(kind='barh', color='yellow')

# Tambah label angka di samping bar
for idx, val in enumerate(attack_src.values):
    plt.text(val, idx, str(val), color='red', va='center', fontsize=10)

plt.xlabel('Number of Requests')
plt.ylabel('IP Address of Sender')
plt.title('Number of Normal Requests per Source IP')
plt.subplots_adjust(left=0.3)  # kasih ruang label IP
plt.show()

# %%
df.head()
# Out:
#         dt  switch       src       dst  pktcount  bytecount    dur   dur_nsec  \
# 0  11425.0       1  10.0.0.1  10.0.0.8     45304   48294064  100.0  716000000
# 1  11605.0       1  10.0.0.1  10.0.0.8    126395  134737070  280.0  734000000
# 2  11425.0       1  10.0.0.2  10.0.0.8     90333   96294978  200.0  744000000
# 3  11425.0       1  10.0.0.2  10.0.0.8     90333   96294978  200.0  744000000
# 4  11425.0       1  10.0.0.2  10.0.0.8     90333   96294978  200.0  744000000
#
#         tot_dur  flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 0  1.010000e+11      3       1943     13535.0   14428310.0    451.0         0
# 1  2.810000e+11      2       1943     13531.0   14424046.0    451.0         0
# 2  2.010000e+11      3       1943     13534.0   14427244.0    451.0         0
# 3  2.010000e+11      3       1943     13534.0   14427244.0    451.0         0
# 4  2.010000e+11      3       1943     13534.0   14427244.0    451.0         0
#
# ...

# %%
df['dur'].nunique()
# Out:
# 840

# %%
df['dur'].unique()
# Out:
# array([1.000e+02, 2.800e+02, 2.000e+02, 2.300e+02, 1.900e+02, 7.300e+01,
#        1.000e+01, 2.500e+02, 8.000e+01, 2.600e+02, 1.600e+02, 1.300e+01,
#        3.100e+02, 2.900e+02, 1.100e+02, 7.000e+01, 4.300e+01, 1.700e+02,
#        5.000e+01, 4.000e+01, 1.400e+02, 1.300e+02, 2.200e+02, 3.200e+02,
#        1.330e+02, 1.030e+02, 3.130e+02, 2.530e+02, 2.830e+02, 1.630e+02,
#        2.230e+02, 1.930e+02, 8.300e+01, 2.000e+01, 3.500e+02, 3.800e+02,
#        2.300e+01, 4.400e+02, 4.100e+02, 4.700e+02, 5.300e+01, 1.020e+02,
#        1.730e+02, 7.200e+01, 2.030e+02, 1.130e+02, 1.430e+02, 1.200e+01,
#        4.200e+01, 2.820e+02, 2.330e+02, 1.320e+02, 3.120e+02, 2.630e+02,
#        2.930e+02, 1.920e+02, 3.230e+02, 2.520e+02, 2.220e+02, 1.620e+02,
#        4.130e+02, 3.530e+02, 3.830e+02, 4.430e+02, 4.730e+02, 3.190e+02,
#        2.700e+02, 3.000e+02, 3.600e+02, 2.890e+02, 3.300e+02, 4.200e+02,
#        3.900e+02, 2.590e+02, 2.400e+02, 4.500e+02, 2.100e+02, 5.200e+01,
# ...

# %%
plt.hist(df['dur'], bins=50, color='b')
plt.xscale('log')
plt.title('Duration (log scale)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df[df['label']==0]['dur'], bins=50, alpha=0.5, label='Normal')
plt.hist(df[df['label']==1]['dur'], bins=50, alpha=0.5, label='Attack')
plt.legend()
plt.xlabel('Duration')
plt.ylabel('Count')
plt.title('Distribution of Duration by Label')
plt.show()

# %%
df['dur'].value_counts()
# Out:
# dur
# 320.0    589
# 290.0    589
# 230.0    585
# 200.0    575
# 50.0     561
#         ...
# 949.0      4
# 889.0      4
# 919.0      4
# 486.0      3
# 509.0      3
# Name: count, Length: 840, dtype: int64

# %%
df['Protocol'].nunique()
# Out:
# 3

# %%
df['Protocol'].unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
df['Protocol'].value_counts()
# Out:
# Protocol
# ICMP    41320
# UDP     33082
# TCP     29436
# Name: count, dtype: int64

# %%
df['Protocol'].value_counts(ascending=True).plot.bar(
    color=['yellow','purple']
)
plt.title('Frekuensi muncul dari Protocol')
plt.xlabel('Protocol')
plt.ylabel('Frekuensi')
plt.xticks(rotation=0)
plt.show()

# %%
# Distribusi label
df['label'].value_counts()
# Out:
# label
# 0    63301
# 1    40350
# Name: count, dtype: int64

# %%
# Rata-rata tx_kbps normal vs attack
df.groupby('label')['tx_kbps'].mean()
# Out:
# label
# 0    1014.997093
# 1     986.588203
# Name: tx_kbps, dtype: float64

# %%
# Rata-rata pktrate normal vs attack pada label
df.groupby('label')['pktrate'].mean()
# Out:
# label
# 0    196.362648
# 1    252.882503
# Name: pktrate, dtype: float64

# %%
Attack = df[df['label']== 1 ]
Attack
# Out:
#            dt  switch       src       dst  pktcount  bytecount  dur  \
# 91      11335       1  10.0.0.1  10.0.0.8      4777    5092282   10
# 92      11335       1  10.0.0.1  10.0.0.8      4777    5092282   10
# 93      11335       1  10.0.0.1  10.0.0.8      4777    5092282   10
# 94      11335       1  10.0.0.1  10.0.0.8      4777    5092282   10
# 95      11335       1  10.0.0.1  10.0.0.8      4777    5092282   10
# ...       ...     ...       ...       ...       ...        ...  ...
# 100037   6552       4  10.0.0.9  10.0.0.6    129558  134999436  448
# 100038   6552       4  10.0.0.9  10.0.0.6    129558  134999436  448
# 100051   6552       3  10.0.0.6  10.0.0.9    129986  135445412  451
# 100052   6552       3  10.0.0.6  10.0.0.9    129986  135445412  451
# 100053   6552       3  10.0.0.6  10.0.0.9    129986  135445412  451
#
#          dur_nsec       tot_dur  flows  ...  pktrate  Pairflow  Protocol  \
# 91      711000000  1.071100e+10      3  ...        0         0       UDP
# ...

# %%
Normal = df[df['label']==0]
Normal
# Out:
#            dt  switch        src       dst  pktcount  bytecount  dur  \
# 0       11425       1   10.0.0.1  10.0.0.8     45304   48294064  100
# 1       11605       1   10.0.0.1  10.0.0.8    126395  134737070  280
# 2       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 3       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 4       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# ...       ...     ...        ...       ...       ...        ...  ...
# 104340   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104341   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104342   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104343   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104344   5262       3  10.0.0.11  10.0.0.5        31       3038   31
#
#          dur_nsec       tot_dur  flows  ...  pktrate  Pairflow  Protocol  \
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(Normal['pktrate'], bins=50, alpha=0.5, label='Normal')
plt.hist(Attack['pktrate'], bins=50, alpha=0.5, label='Attack')
plt.legend()
plt.xlabel('pktrate')
plt.ylabel('frekuensi')
plt.title('Distribusi Packet Rate: Normal vs Attack')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
